# %% [markdown]
# ##  Setup

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy

import librosa 
import librosa.display # !!!!

# %% [markdown]
# LibROSA is a python package for music and audio analysis. It provides the building blocks necessary to create music information retrieval systems.

# %%
import mir_eval # Music Information Retrieval systems
from IPython.display import Audio

# %% [markdown]
# ### Setup audio file

# %% [raw]
# y = data
# sr = sample rate (Hz)
# frame = short audio clip (< > spectogram column)
# n_fft = samples per frame
# hop_lenght = # samples between frames

# %%
y, sr = librosa.load('talk.wav')

# %%
print (type(y), type(sr))
# Out:
# <class 'numpy.ndarray'> <class 'int'>

# %%
print(y.shape, sr)
# Out:
# (153706,) 22050

# %%
# play audio in jupyter
Audio(data=y, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Plot waveform

# %%
librosa.display.waveplot(y,sr)

# %% [markdown]
# ## Spectogram

# %%
D = librosa.amplitude_to_db(np.abs(librosa.stft(y)), ref=np.max)

# %%
librosa.display.specshow(D, y_axis='log', x_axis='time')

# %%
librosa.display.specshow(D, y_axis='linear', x_axis='time')

# %%
librosa.display.specshow(D, y_axis='mel', x_axis='time')
